# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Loading API Credentials
with open('/Users/LP-Ca/.secret/yelp_api.json') as f:
    creds = json.load(f)
creds.keys()
# Out:
# dict_keys(['client id', 'API key'])

# %%
# Instantiating YelpAPI Variable
yelp_api = YelpAPI(creds['API key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# Performing API call
pizza_1 = yelp_api.search_query(location='New London, CT', 
                                term='pizza')

type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# Checking total number of results
results['total']
# Out:
# 74

# %%
# Reading API call results into a dataframe
pizza1 = pd.DataFrame(pizza_1['businesses'])
pizza1.head()
# Out:
#                        id                                             alias  \
# 0  BV_Q5naKT8PZ5eq8zCrs8Q                          college-pizza-new-london
# 1  nBLNQRqPoAW4bifo-jBbOg                      napolitanos-pizza-new-london
# 2  09LlawnbCnT2I3OdJ-UIAA  woodfellas-wood-fired-pizza-and-wings-new-london
# 3  oJkBL9rbTzrBJXMM-CGz9w                 ocean-pizza-restaurant-new-london
# 4  rX2R2xYhmc_cSYbU2Cq4zw                         the-rolling-tomato-groton
#
#                                   name  \
# 0                        College Pizza
# 1                   Napolitano's Pizza
# 2  Woodfellas Wood Fired Pizza & Wings
# 3               Ocean Pizza Restaurant
# 4                   The Rolling Tomato
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/hrU90b...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/TH1m6G...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/cpNUz0...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/i_JxQM...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/ato1r6...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/college-pizza-new-lon...             9
# 1  https://www.yelp.com/biz/napolitanos-pizza-new...            26
# 2  https://www.yelp.com/biz/woodfellas-wood-fired...             3
# 3  https://www.yelp.com/biz/ocean-pizza-restauran...            84
# 4  https://www.yelp.com/biz/the-rolling-tomato-gr...           218
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 2  [{'alias': 'chicken_wings', 'title': 'Chicken ...     3.5
# 3  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 4  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 41.33407, 'longitude': -72.097262}          [delivery]
# 1  {'latitude': 41.3519659513244, 'longitude': -7...  [delivery, pickup]
# 2  {'latitude': 41.35424387620893, 'longitude': -...                  []
# 3   {'latitude': 41.345451, 'longitude': -72.107352}  [delivery, pickup]
# 4   {'latitude': 41.353711, 'longitude': -72.060276}          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '262 Pequot Ave', 'address2': '',...  +18605749955
# 1  {'address1': '211 Bank St', 'address2': None, ...  +18604403777
# 2  {'address1': '45 Huntington St', 'address2': '...  +18604479337
# 3  {'address1': '88 Ocean Ave', 'address2': '', '...  +18604430870
# 4  {'address1': '505 Long Hill Rd', 'address2': '...  +18604459663
#
#     display_phone     distance price
# 0  (860) 574-9955  2284.228381   NaN
# 1  (860) 440-3777   780.523632     $
# 2  (860) 447-9337   561.861955   NaN
# 3  (860) 443-0870   914.864175    $$
# 4  (860) 445-9663  3789.355430    $$

# %% [markdown]
# Pagination

# %%
# adding offset to original api call
pizza_2 = yelp_api.search_query(location='New London, CT9',
                                term='pizza',
                                offset = 20)

# %%
# Checking API call results after pagination
pizza2 = pd.DataFrame(pizza_2['businesses'])
pizza2.head()
# Out:
#                        id                              alias  \
# 0  lHpGGbjFwTwXvyoTaQGKBw              pizza-palace-groton-2
# 1  wYWEPx9EQOOSPGW0-vldgA  wingsn-pies-new-london-new-london
# 2  3r0oA9hgvQKyalUq3UO3zQ                wings-n-pies-groton
# 3  GX7EDx0cJUzF5IMFZysoHA            empire-pizza-new-london
# 4  il50l2rhv_EQ_NivRRPFnw                 pizza-today-groton
#
#                        name  \
# 0              Pizza Palace
# 1  Wings'N' Pies New London
# 2            Wings 'N' Pies
# 3              Empire Pizza
# 4               Pizza Today
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/4XLepQ...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/RI_9CS...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/I3T9iS...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/5vNZlJ...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/p4xHMn...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/pizza-palace-groton-2...            27
# 1  https://www.yelp.com/biz/wingsn-pies-new-londo...            83
# 2  https://www.yelp.com/biz/wings-n-pies-groton?a...            44
# 3  https://www.yelp.com/biz/empire-pizza-new-lond...            18
# 4  https://www.yelp.com/biz/pizza-today-groton?ad...            35
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1  [{'alias': 'chicken_wings', 'title': 'Chicken ...     3.0
# 2  [{'alias': 'chicken_wings', 'title': 'Chicken ...     3.5
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     2.0
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     2.5
#
#                                          coordinates        transactions  \
# 0     {'latitude': 41.34681, 'longitude': -72.05009}          [delivery]
# 1  {'latitude': 41.35476417, 'longitude': -72.095...  [pickup, delivery]
# 2  {'latitude': 41.3866321812443, 'longitude': -7...          [delivery]
# 3  {'latitude': 41.3585170358419, 'longitude': -7...          [delivery]
# 4       {'latitude': 41.3479, 'longitude': -72.0753}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '944 Poquonnock Rd', 'address2': ...  +18604451111
# 1     $  {'address1': '131 State St', 'address2': None,...  +18604424700
# 2   NaN  {'address1': '924 CT-12', 'address2': '', 'add...  +18604058200
# 3     $  {'address1': '150 Broad St', 'address2': '', '...  +18604370835
# 4    $$  {'address1': '344 Mitchell St', 'address2': ''...  +18604454012
#
#     display_phone     distance
# 0  (860) 445-1111  4699.257685
# 1  (860) 442-4700   855.113095
# 2  (860) 405-8200  4321.630675
# 3  (860) 437-0835   553.639834
# 4  (860) 445-4012  2613.637256

# %%
# Concatenating results into one dataframe
businesses = pd.concat([pizza1, pizza2],
                       ignore_index=True)
display(businesses.head(), businesses.tail())
# Out:
#                        id                                             alias  \
# 0  BV_Q5naKT8PZ5eq8zCrs8Q                          college-pizza-new-london
# 1  nBLNQRqPoAW4bifo-jBbOg                      napolitanos-pizza-new-london
# 2  09LlawnbCnT2I3OdJ-UIAA  woodfellas-wood-fired-pizza-and-wings-new-london
# 3  oJkBL9rbTzrBJXMM-CGz9w                 ocean-pizza-restaurant-new-london
# 4  rX2R2xYhmc_cSYbU2Cq4zw                         the-rolling-tomato-groton
#
#                                   name  \
# 0                        College Pizza
# 1                   Napolitano's Pizza
# 2  Woodfellas Wood Fired Pizza & Wings
# 3               Ocean Pizza Restaurant
# 4                   The Rolling Tomato
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/hrU90b...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/TH1m6G...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/cpNUz0...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/i_JxQM...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/ato1r6...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/college-pizza-new-lon...             9
# 1  https://www.yelp.com/biz/napolitanos-pizza-new...            26
# 2  https://www.yelp.com/biz/woodfellas-wood-fired...             3
# 3  https://www.yelp.com/biz/ocean-pizza-restauran...            84
# 4  https://www.yelp.com/biz/the-rolling-tomato-gr...           218
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 2  [{'alias': 'chicken_wings', 'title': 'Chicken ...     3.5
# 3  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 4  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 41.33407, 'longitude': -72.097262}          [delivery]
# 1  {'latitude': 41.3519659513244, 'longitude': -7...  [delivery, pickup]
# 2  {'latitude': 41.35424387620893, 'longitude': -...                  []
# 3   {'latitude': 41.345451, 'longitude': -72.107352}  [delivery, pickup]
# 4   {'latitude': 41.353711, 'longitude': -72.060276}          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '262 Pequot Ave', 'address2': '',...  +18605749955
# 1  {'address1': '211 Bank St', 'address2': None, ...  +18604403777
# 2  {'address1': '45 Huntington St', 'address2': '...  +18604479337
# 3  {'address1': '88 Ocean Ave', 'address2': '', '...  +18604430870
# 4  {'address1': '505 Long Hill Rd', 'address2': '...  +18604459663
#
#     display_phone     distance price
# 0  (860) 574-9955  2284.228381   NaN
# 1  (860) 440-3777   780.523632     $
# 2  (860) 447-9337   561.861955   NaN
# 3  (860) 443-0870   914.864175    $$
# 4  (860) 445-9663  3789.355430    $$
#                         id                                        alias  \
# 35  6wa0tnMN_q2SrkrWf9auVQ              guss-pizza-and-bar-new-london-2
# 36  SxjVQMIpmK6nOa9R0aiBaQ                   papa-johns-pizza-waterford
# 37  6Hz0J-2KWuE9NGDcJdrWMw                    black-point-pizza-niantic
# 38  JhtIdUe9A8t_xDfQ7u4SAg  the-spice-palette-indian-cuisine-new-london
# 39  jeOcG-fu3o-7f8DD8wJS6A           crown-chicken-and-grill-new-london
#
#                                 name  \
# 35                 Gus's Pizza & Bar
# 36                  Papa Johns Pizza
# 37                 Black Point Pizza
# 38  The Spice Palette Indian Cuisine
# 39           Crown Chicken and Grill
#
#                                             image_url  is_closed  \
# 35  https://s3-media4.fl.yelpcdn.com/bphoto/qOk_Qd...      False
# 36  https://s3-media4.fl.yelpcdn.com/bphoto/_x1mYl...      False
# 37  https://s3-media3.fl.yelpcdn.com/bphoto/DqmjHp...      False
# 38  https://s3-media2.fl.yelpcdn.com/bphoto/o4xhbO...      False
# 39  https://s3-media4.fl.yelpcdn.com/bphoto/qWLRrM...      False
#
#                                                   url  review_count  \
# 35  https://www.yelp.com/biz/guss-pizza-and-bar-ne...            12
# 36  https://www.yelp.com/biz/papa-johns-pizza-wate...             5
# 37  https://www.yelp.com/biz/black-point-pizza-nia...            28
# 38  https://www.yelp.com/biz/the-spice-palette-ind...            18
# 39  https://www.yelp.com/biz/crown-chicken-and-gri...            19
#
#                                            categories  rating  \
# 35  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.5
# 36  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 37  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 38           [{'alias': 'indpak', 'title': 'Indian'}]     5.0
# 39  [{'alias': 'cheesesteaks', 'title': 'Cheeseste...     4.0
#
#                                           coordinates        transactions  \
# 35  {'latitude': 41.3541056848572, 'longitude': -7...  [pickup, delivery]
# 36   {'latitude': 41.341269, 'longitude': -72.123316}  [pickup, delivery]
# 37   {'latitude': 41.319016, 'longitude': -72.204629}          [delivery]
# 38       {'latitude': 41.34659, 'longitude': -72.111}  [pickup, delivery]
# 39     {'latitude': 41.34617, 'longitude': -72.11042}  [pickup, delivery]
#
#                                              location         phone  \
# 35  {'address1': '24 Eugene O'Neill Dr', 'address2...  +18604400706
# 36  {'address1': '106 Boston Post Road', 'address2...  +18604427272
# 37  {'address1': '44 Black Point Rd', 'address2': ...  +18604518444
# 38  {'address1': '929 Bank St', 'address2': None, ...  +19592016913
# 39  {'address1': '922 Bank St', 'address2': None, ...
#
#      display_phone     distance price
# 35  (860) 440-0706   848.519424    $$
# 36  (860) 442-7272  2012.651607     $
# 37  (860) 451-8444  9105.153595   NaN
# 38  (959) 201-6913   901.163561    $$
# 39                   908.445273     $
