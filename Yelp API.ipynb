# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Loading API Credentials
with open('/Users/LP-Ca/.secret/yelp_api.json') as f:
    creds = json.load(f)
creds.keys()
# Out:
# dict_keys(['client id', 'API key'])

# %%
# Instantiating YelpAPI Variable
yelp_api = YelpAPI(creds['API key'])
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# Performing API call
results = yelp_api.search_query(location='Pawcatuck, CT,06379', 
                                term='Burgers')

type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# Checking total number of results
results['total']
# Out:
# 29

# %%
# Reading API call results into a dataframe
biz = pd.DataFrame(results['businesses'])
biz.head()
# Out:
#                        id                        alias  \
# 0  sODdKPCWnkYxQ9BxP0aNGw  b-and-b-dockside-westerly-2
# 1  SEUBkQCAhdkKRUjXUdVO2w       graze-burgers-westerly
# 2  ydxhFI0FRgLjhex8pNC5Iw   the-malted-barley-westerly
# 3  8gXaeFOak_To2t2xvtWUQw        the-shallows-westerly
# 4  AxGW4itHJXGh8oqZVsjRug   bridge-restaurant-westerly
#
#                                       name  \
# 0                           B & B Dockside
# 1                            Graze Burgers
# 2                        The Malted Barley
# 3                             The Shallows
# 4  Bridge Restaurant [Raw Bar] River Patio
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/jpeD0p...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/1XCzJ6...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/00N8ZI...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/WzE-Br...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/6bCQn4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/b-and-b-dockside-west...           136
# 1  https://www.yelp.com/biz/graze-burgers-westerl...           111
# 2  https://www.yelp.com/biz/the-malted-barley-wes...           299
# 3  https://www.yelp.com/biz/the-shallows-westerly...            58
# 4  https://www.yelp.com/biz/bridge-restaurant-wes...           385
#
#                                           categories  rating  \
# 0  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 2  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 3  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 4  [{'alias': 'newamerican', 'title': 'American (...     3.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 41.3670539855957, 'longitude': -7...          [delivery]
# 1  {'latitude': 41.37068576556191, 'longitude': -...          [delivery]
# 2       {'latitude': 41.3788, 'longitude': -71.8303}  [pickup, delivery]
# 3   {'latitude': 41.379296, 'longitude': -71.830527}          [delivery]
# 4   {'latitude': 41.376973, 'longitude': -71.831896}          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '19 Margin St', 'address2': '', '...  +14013152520
# 1   NaN  {'address1': '127 Granite St', 'address2': Non...  +14019928223
# 2    $$  {'address1': '42 High St', 'address2': None, '...  +14013152184
# 3    $$  {'address1': '54 High St', 'address2': '', 'ad...  +14013155737
# 4    $$  {'address1': '37 Main St', 'address2': '', 'ad...  +14013489700
#
#     display_phone     distance
# 0  (401) 315-2520  1722.989668
# 1  (401) 992-8223  2575.705237
# 2  (401) 315-2184  1645.153838
# 3  (401) 315-5737  1631.203716
# 4  (401) 348-9700  1502.652791

# %% [markdown]
# Pagination

# %%
# adding offset to original api call
results = yelp_api.search_query(location='Pawcatuck, CT,06379',
                                term='burgers',
                                offset = 20)

# %%
# Checking API call results after pagination
biz20 = pd.DataFrame(results['businesses'])
biz20.head()
# Out:
#                        id                               alias  \
# 0  ptDQh4fgys1UXXdpnYNTGQ   marios-northend-pizzaria-westerly
# 1  37mieC3J4TfBN9V9PP8Weg  ellas-fine-food-and-drink-westerly
# 2  AsgXKlsP4NYfaguFV7g-6Q           99-restaurants-westerly-2
# 3  Ed8ru91OfHgjnADWlA0KDg         cleats-sports-club-westerly
# 4  y-j-6uE793oUwm9b5LG58A                burger-king-westerly
#
#                         name  \
# 0  Mario's Northend Pizzaria
# 1   Ella's Fine Food & Drink
# 2             99 Restaurants
# 3         Cleats Sports Club
# 4                Burger King
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/gIeYKh...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/x_zUcV...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/w0LU7R...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/3peld2...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/PKl8O0...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/marios-northend-pizza...            23
# 1  https://www.yelp.com/biz/ellas-fine-food-and-d...           199
# 2  https://www.yelp.com/biz/99-restaurants-wester...            34
# 3  https://www.yelp.com/biz/cleats-sports-club-we...             5
# 4  https://www.yelp.com/biz/burger-king-westerly?...             7
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 1  [{'alias': 'french', 'title': 'French'}, {'ali...     4.0
# 2  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     3.0
# 3  [{'alias': 'newamerican', 'title': 'American (...     3.0
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     1.5
#
#                                          coordinates transactions price  \
# 0     {'latitude': 41.38323, 'longitude': -71.82628}   [delivery]    $$
# 1     {'latitude': 41.37424, 'longitude': -71.82034}   [delivery]   $$$
# 2  {'latitude': 41.3570750896787, 'longitude': -7...           []    $$
# 3  {'latitude': 41.37150164057659, 'longitude': -...   [delivery]    $$
# 4   {'latitude': 41.360979, 'longitude': -71.812403}   [delivery]     $
#
#                                             location         phone  \
# 0  {'address1': '61 Friendship St', 'address2': '...  +14015963883
# 1  {'address1': '2 Tower St', 'address2': None, '...  +14013150606
# 2  {'address1': '7 Airport Rd', 'address2': '', '...  +14013488299
# 3  {'address1': '116 Granite St', 'address2': '',...  +14015964107
# 4  {'address1': '99 Franklin St', 'address2': '',...  +14014439401
#
#     display_phone     distance
# 0  (401) 596-3883  2056.917063
# 1  (401) 315-0606  2485.651513
# 2  (401) 348-8299  4140.640047
# 3  (401) 596-4107  2673.919783
# 4  (401) 443-9401  3618.968790

# %%
# Concatenating results into one dataframe
businesses = pd.concat([biz, biz20],
                       ignore_index=True)
display(businesses.head(), businesses.tail())
# Out:
#                        id                        alias  \
# 0  sODdKPCWnkYxQ9BxP0aNGw  b-and-b-dockside-westerly-2
# 1  SEUBkQCAhdkKRUjXUdVO2w       graze-burgers-westerly
# 2  ydxhFI0FRgLjhex8pNC5Iw   the-malted-barley-westerly
# 3  8gXaeFOak_To2t2xvtWUQw        the-shallows-westerly
# 4  AxGW4itHJXGh8oqZVsjRug   bridge-restaurant-westerly
#
#                                       name  \
# 0                           B & B Dockside
# 1                            Graze Burgers
# 2                        The Malted Barley
# 3                             The Shallows
# 4  Bridge Restaurant [Raw Bar] River Patio
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/jpeD0p...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/1XCzJ6...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/00N8ZI...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/WzE-Br...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/6bCQn4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/b-and-b-dockside-west...           136
# 1  https://www.yelp.com/biz/graze-burgers-westerl...           111
# 2  https://www.yelp.com/biz/the-malted-barley-wes...           299
# 3  https://www.yelp.com/biz/the-shallows-westerly...            58
# 4  https://www.yelp.com/biz/bridge-restaurant-wes...           385
#
#                                           categories  rating  \
# 0  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.5
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.5
# 2  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5
# 3  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 4  [{'alias': 'newamerican', 'title': 'American (...     3.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 41.3670539855957, 'longitude': -7...          [delivery]
# 1  {'latitude': 41.37068576556191, 'longitude': -...          [delivery]
# 2       {'latitude': 41.3788, 'longitude': -71.8303}  [pickup, delivery]
# 3   {'latitude': 41.379296, 'longitude': -71.830527}          [delivery]
# 4   {'latitude': 41.376973, 'longitude': -71.831896}          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '19 Margin St', 'address2': '', '...  +14013152520
# 1   NaN  {'address1': '127 Granite St', 'address2': Non...  +14019928223
# 2    $$  {'address1': '42 High St', 'address2': None, '...  +14013152184
# 3    $$  {'address1': '54 High St', 'address2': '', 'ad...  +14013155737
# 4    $$  {'address1': '37 Main St', 'address2': '', 'ad...  +14013489700
#
#     display_phone     distance
# 0  (401) 315-2520  1722.989668
# 1  (401) 992-8223  2575.705237
# 2  (401) 315-2184  1645.153838
# 3  (401) 315-5737  1631.203716
# 4  (401) 348-9700  1502.652791
#                         id                             alias  \
# 24  y-j-6uE793oUwm9b5LG58A              burger-king-westerly
# 25  R5lqc3m3nSoTpiV2zwTzYg               mcdonalds-pawcatuck
# 26  ScWo9UTVDqOiQMQ5_MLGgw  d-angelos-sandwich-shop-westerly
# 27  QRrCR0xAc1-c-y635OtUWg              mcdonalds-westerly-2
# 28  eq5JhKEVOfxY6zV9ZlRGsA                 subway-westerly-7
#
#                         name  \
# 24               Burger King
# 25                McDonald's
# 26  D'angelo's Sandwich Shop
# 27                McDonald's
# 28                    Subway
#
#                                             image_url  is_closed  \
# 24  https://s3-media2.fl.yelpcdn.com/bphoto/PKl8O0...      False
# 25  https://s3-media1.fl.yelpcdn.com/bphoto/_zMkYX...      False
# 26  https://s3-media4.fl.yelpcdn.com/bphoto/UjbhFa...      False
# 27  https://s3-media3.fl.yelpcdn.com/bphoto/Mu8XN-...      False
# 28  https://s3-media3.fl.yelpcdn.com/bphoto/90SgbD...      False
#
#                                                   url  review_count  \
# 24  https://www.yelp.com/biz/burger-king-westerly?...             7
# 25  https://www.yelp.com/biz/mcdonalds-pawcatuck?a...            24
# 26  https://www.yelp.com/biz/d-angelos-sandwich-sh...             4
# 27  https://www.yelp.com/biz/mcdonalds-westerly-2?...            25
# 28  https://www.yelp.com/biz/subway-westerly-7?adj...             9
#
#                                            categories  rating  \
# 24  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     1.5
# 25  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 26   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     3.5
# 27  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 28   [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     2.5
#
#                                           coordinates transactions price  \
# 24   {'latitude': 41.360979, 'longitude': -71.812403}   [delivery]     $
# 25  {'latitude': 41.4058873934944, 'longitude': -7...   [delivery]     $
# 26     {'latitude': 41.37385, 'longitude': -71.82076}   [delivery]    $$
# 27  {'latitude': 41.3703304567745, 'longitude': -7...   [delivery]     $
# 28  {'latitude': 41.363883679266344, 'longitude': ...           []     $
#
#                                              location         phone  \
# 24  {'address1': '99 Franklin St', 'address2': '',...  +14014439401
# 25  {'address1': '465 Liberty St', 'address2': '',...  +18605999903
# 26  {'address1': '85 Granite St', 'address2': '', ...  +14015966363
# 27  {'address1': '135 Granite St', 'address2': '',...  +14015969086
# 28  {'address1': '62 Franklin St Units 1 & 2', 'ad...  +14015969220
#
#      display_phone     distance
# 24  (401) 443-9401  3618.968790
# 25  (860) 599-9903  3176.532897
# 26  (401) 596-6363  2442.892600
# 27  (401) 596-9086  2572.092710
# 28  (401) 596-9220  3275.786796
